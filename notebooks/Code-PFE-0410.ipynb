# %%
# !pip install openmeteo-requests
# !pip install requests-cache retry-requests numpy pandas matplotlib scipy cartopy openmeteo_requests retry_requests fipy
# Out:
# Requirement already satisfied: openmeteo-requests in /home/hleroy/mon_venv/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: openmeteo-sdk>=1.4.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from openmeteo-requests) (1.16.0)
# Requirement already satisfied: requests in /home/hleroy/mon_venv/lib/python3.12/site-packages (from openmeteo-requests) (2.32.3)
# Requirement already satisfied: flatbuffers>=24.0.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from openmeteo-sdk>=1.4.0->openmeteo-requests) (24.3.25)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests->openmeteo-requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests->openmeteo-requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests->openmeteo-requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests->openmeteo-requests) (2024.8.30)
# Requirement already satisfied: requests-cache in /home/hleroy/mon_venv/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: retry-requests in /home/hleroy/mon_venv/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: numpy in /home/hleroy/mon_venv/lib/python3.12/site-packages (2.1.1)
# Requirement already satisfied: pandas in /home/hleroy/mon_venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /home/hleroy/mon_venv/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: scipy in /home/hleroy/mon_venv/lib/python3.12/site-packages (1.14.1)
# Requirement already satisfied: cartopy in /home/hleroy/mon_venv/lib/python3.12/site-packages (0.23.0)
# Requirement already satisfied: openmeteo_requests in /home/hleroy/mon_venv/lib/python3.12/site-packages (1.3.0)
# Requirement already satisfied: fipy in /home/hleroy/mon_venv/lib/python3.12/site-packages (3.4.5)
# Requirement already satisfied: attrs>=21.2 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests-cache) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests-cache) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests-cache) (4.3.6)
# Requirement already satisfied: requests>=2.22 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests-cache) (2.32.3)
# Requirement already satisfied: url-normalize>=1.4 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests-cache) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: shapely>=1.7 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from cartopy) (2.0.6)
# Requirement already satisfied: pyshp>=2.3 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from cartopy) (3.7.0)
# Requirement already satisfied: openmeteo-sdk>=1.4.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from openmeteo_requests) (1.16.0)
# Requirement already satisfied: future in /home/hleroy/mon_venv/lib/python3.12/site-packages (from fipy) (1.0.0)
# Requirement already satisfied: flatbuffers>=24.0.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from openmeteo-sdk>=1.4.0->openmeteo_requests) (24.3.25)
# Requirement already satisfied: certifi in /home/hleroy/mon_venv/lib/python3.12/site-packages (from pyproj>=3.3.1->cartopy) (2024.8.30)
# Requirement already satisfied: six>=1.5 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from requests>=2.22->requests-cache) (3.10)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import geopandas as gpd
import cartopy.crs as ccrs

# %%
nlat = 0.1
nlong = 0.1

# %%
latitudes = np.arange(41.5, 43.02, nlat)
longitudes = np.arange(8.5, 9.52, nlong)

# %%
print(latitudes)
print(longitudes)
# Out:
# [41.5 41.6 41.7 41.8 41.9 42.  42.1 42.2 42.3 42.4 42.5 42.6 42.7 42.8
#  42.9 43. ]
# [8.5 8.6 8.7 8.8 8.9 9.  9.1 9.2 9.3 9.4 9.5]

# %%
latitudes_list = latitudes.round(1).tolist()
longitudes_list = longitudes.round(1).tolist()

# %%
l_latitudes = np.repeat(latitudes_list, len(longitudes)).tolist()
l_longitudes = np.tile(longitudes_list, len(latitudes)).tolist()

# %%
#print(l_latitudes)
#print(l_longitudes)

# %%
import openmeteo_requests

import requests_cache
import pandas as pd
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://archive-api.open-meteo.com/v1/archive"
params = {
	"latitude": l_latitudes,
	"longitude": l_longitudes,
	"start_date": "2024-09-09",
	"end_date": "2024-09-09",
	"hourly": ["wind_speed_10m", "wind_direction_10m", "wind_speed_80m", "wind_direction_80m"]
    "temporal_resolution": "hourly_6"
}
responses = openmeteo.weather_api(url, params=params)
# Out:
#   Cell In[9], line 20
#     "hourly": ["wind_speed_10m", "wind_direction_10m", "wind_speed_80m", "wind_direction_80m"]
#               ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(responses[0].Hourly().Variables(3).ValuesAsNumpy())

# %%
# Création du DataFrame à partir des coordonnées
wind_data = pd.DataFrame({'lat': l_latitudes, 'lon': l_longitudes, 'u': 0.0, 'v':0.0})

# %%
print(wind_data)

# %%
for i in range(len(l_latitudes)): #l_latitude correspond au nombre de points de la grille
    data = responses[i] #On prend le i-ème point de la grille
    hourl = data.Hourly() #On va chercher les données par heure
    hourl_wind_speed_10m = hourl.Variables(0).ValuesAsNumpy()
    hourl_wind_direction_10m = hourl.Variables(1).ValuesAsNumpy()
    hourl_data = {"date": pd.date_range(
        start = pd.to_datetime(hourl.Time(), unit = "s", utc = True),
        end = pd.to_datetime(hourl.TimeEnd(), unit = "s", utc = True),
        freq = pd.Timedelta(seconds = hourl.Interval()),
        inclusive = "left"
    )}
    hourl_data["wind_speed_10m"] = hourl_wind_speed_10m
    hourl_data["wind_direction_10m"] = hourl_wind_direction_10m

    hourl_dataframe = pd.DataFrame(data = hourl_data)
    
    wind_spd_tmp = hourl_data["wind_speed_10m"][0] #0 correspond à l'heure 0h00 de la journée du 09/09/2024
    wind_dir_tmp = hourl_data["wind_direction_10m"][0]
    wind_direction_radians = np.deg2rad(wind_dir_tmp)
    
    wind_data.at[i, 'u'] = wind_spd_tmp * np.cos(wind_direction_radians)
    wind_data.at[i, 'v'] = wind_spd_tmp * np.sin(wind_direction_radians)

# %%
#print(wind_data.tail(20))

# %%
# Création de la carte
plt.figure(figsize=(10, 8))
ax = plt.axes(projection=ccrs.Mercator())

# Tracer les contours de la Corse
ax.coastlines()
ax.set_extent([8.25, 9.6, 41.2, 43.1], crs=ccrs.PlateCarree())
ax.set_title("Direction et vitesse du vent à l'heure 0")


ax.quiver(wind_data['lon'], wind_data['lat'], wind_data['u'], wind_data['v'], scale=100, transform=ccrs.PlateCarree(), color='r')

plt.show()

# %% [markdown]
# ## Interpolation avec scipy.interpolate as interp

# %%
t1, t2 = np.meshgrid(latitudes, longitudes)

# %%
print(t1.shape, t2.shape)
# Out:
# (11, 16) (11, 16)

# %%
wind_data['u']
# Out:
# 0       8.640039
# 1       8.640039
# 2       6.840027
# 3       5.400022
# 4       5.400022
#          ...
# 171   -12.960060
# 172   -13.320050
# 173   -12.960073
# 174   -12.960073
# 175    -7.919970
# Name: u, Length: 176, dtype: float64

# %% [markdown]
# https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.interpolate.interp2d.html#scipy.interpolate.interp2d
#
# kind : {‘linear’, ‘cubic’, ‘quintic’}, optional
#
#     The kind of spline interpolation to use. Default is ‘linear’.

# %%
from scipy.interpolate import interp2d, RectBivariateSpline
wind_data_u_grid = np.empty([len(latitudes), len(longitudes)], dtype = float)
print(wind_data_u_grid.shape)
wind_data_u_grid[:] = wind_data['u'].values[:wind_data_u_grid.size].reshape((16,11))
# Out:
# (16, 11)

# %%
import time

# %%
# %%time
f_u = interp2d(longitudes,latitudes, wind_data_u_grid, kind='cubic')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/mon_venv/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:129, in interp2d.__init__(self, x, y, z, kind, copy, bounds_error, fill_value)
#     127 def __init__(self, x, y, z, kind='linear', copy=True, bounds_error=False,
#     128              fill_value=None):
# --> 129     raise NotImplementedError(err_mesg)
#
# NotImplementedError: `interp2d` has been removed in SciPy 1.14.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# https://scipy.github.io/devdocs/tutorial/interpolate/interp_transition_guide.html

# %%
print(longitudes.size, wind_data_u_grid.shape)
# Out:
# 11 (16, 11)

# %%
from scipy.interpolate import interp2d, RectBivariateSpline
wind_data_v_grid = np.empty([len(latitudes), len(longitudes)], dtype = float)
print(wind_data_v_grid.shape)
wind_data_v_grid[:] = wind_data['v'].values[:wind_data_v_grid.size].reshape((16,11))

f_v = interp2d(longitudes,latitudes, wind_data_v_grid, kind='cubic')
# Out:
# (16, 11)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[21], line 6
#       3 print(wind_data_v_grid.shape)
#       4 wind_data_v_grid[:] = wind_data['v'].values[:wind_data_v_grid.size].reshape((16,11))
# ----> 6 f_v = interp2d(longitudes,latitudes, wind_data_v_grid, kind='cubic')
#
# File ~/mon_venv/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:129, in interp2d.__init__(self, x, y, z, kind, copy, bounds_error, fill_value)
#     127 def __init__(self, x, y, z, kind='linear', copy=True, bounds_error=False,
#     128              fill_value=None):
# --> 129     raise NotImplementedError(err_mesg)
#
# NotImplementedError: `interp2d` has been removed in SciPy 1.14.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# https://scipy.github.io/devdocs/tutorial/interpolate/interp_transition_guide.html

# %%
def plot(f, xnew, ynew, wind_data_grid):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
    znew = f(xnew, ynew)
    ax1.plot(longitudes, wind_data_grid[0, :], 'ro-', xnew, znew[0, :], 'b-')
    im = ax2.imshow(znew)
    plt.colorbar(im, ax=ax2)
    plt.show()
    return znew

# %%
print(wind_data_v_grid.shape, len(longitudes), len(latitudes))
# Out:
# (16, 11) 11 16

# %%
from scipy.interpolate import RectBivariateSpline
latitudes_interp = np.arange(41.5, 43.001, 1e-2)
longitudes_interp = np.arange(8.5, 9.5001, 1e-2)
#wind_data_interp_u = plot(f_u, longitudes_interp, latitudes_interp, wind_data_u_grid)
wind_data_u_grid = np.empty([len(latitudes), len(longitudes)], dtype = float)
wind_data_u_grid[:] = wind_data['u'].values[:wind_data_u_grid.size].reshape((16,11))

wind_data_v_grid = np.empty([len(latitudes), len(longitudes)], dtype = float)
wind_data_v_grid[:] = wind_data['v'].values[:wind_data_v_grid.size].reshape((16,11))

# %%
# %%time
test_u_interp = RectBivariateSpline(latitudes,longitudes,wind_data_u_grid, bbox=[min(latitudes), max(latitudes), min(longitudes), max(longitudes)])
# Out:
# CPU times: user 338 μs, sys: 25 μs, total: 363 μs
# Wall time: 372 μs

# %%
# %%time
test_v_interp = RectBivariateSpline(latitudes,longitudes,wind_data_v_grid, bbox=[min(latitudes), max(latitudes), min(longitudes), max(longitudes)])
# Out:
# CPU times: user 430 μs, sys: 0 ns, total: 430 μs
# Wall time: 438 μs

# %%
u_interpolated = test_u_interp(latitudes_interp, longitudes_interp)
v_interpolated = test_v_interp(latitudes_interp, longitudes_interp)

# %%
# Création d'une figure avec deux sous-graphes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))

# Carte de u_interpolated
contour_u = ax1.contourf(longitudes_interp, latitudes_interp, u_interpolated, cmap='coolwarm')
ax1.set_title('Interpolation des valeurs de vent (u)')
ax1.set_xlabel('Longitude')
ax1.set_ylabel('Latitude')
fig.colorbar(contour_u, ax=ax1, label='Valeur du vent (u) interpolé')

# Carte de v_interpolated
contour_v = ax2.contourf(longitudes_interp, latitudes_interp, v_interpolated, cmap='coolwarm')
ax2.set_title('Interpolation des valeurs de vent (v)')
ax2.set_xlabel('Longitude')
ax2.set_ylabel('Latitude')
fig.colorbar(contour_v, ax=ax2, label='Valeur du vent (v) interpolé')

# Affiche les deux cartes côte à côte
plt.tight_layout()
plt.show()

# %% [markdown]
# v_interpolated = test_v_interp(latitudes_interp, longitudes_interp)

# %% [markdown]
# # Fipy

# %%
from fipy import CellVariable, FaceVariable, Grid2D, DiffusionTerm, Viewer
from fipy.tools import numerix

# %%
from fipy import CellVariable, FaceVariable, Grid2D, DiffusionTerm, Viewer
from fipy.tools import numerix
mesh = Grid2D(nx = len(latitudes), ny = len(longitudes), dx = nlong, dy = nlat)
pressure = CellVariable(mesh = mesh, name = 'pressure')
pressureCorrection = CellVariable(mesh = mesh)
uVelocity = CellVariable(mesh = mesh, name = 'u velocity')
vVelocity = CellVariable(mesh = mesh, name = 'v velocity')
velocity = FaceVariable(mesh = mesh, rank=1) 
viscosity = 14.88 * 10e-6
u_ = 1. 
pressureRelaxation = 0.8
velocityRelaxation = 0.5
if __name__ == '__main__':
    sweeps = 300
else:
    sweeps = 5
uVelocityEq = DiffusionTerm(coeff=viscosity) -  pressure.grad.dot([1., 0.])
vVelocityEq = DiffusionTerm(coeff=viscosity) -  pressure.grad.dot([0., 1.])
ap = CellVariable(mesh = mesh, value = 1.)
coeff = 1./ap.arithmeticFaceValue*mesh._faceAreas * mesh._cellDistances
pressureCorrectionEq = DiffusionTerm(coeff = coeff) - velocity.divergence
from fipy.variables.faceGradVariable import _FaceGradVariable
volume = CellVariable(mesh = mesh, value = mesh.cellVolumes, name="Volume")
contrvolume = volume.arithmeticFaceValue
uVelocity.constrain(0., mesh.facesRight | mesh.facesLeft | mesh.facesBottom)
uVelocity.constrain(u_, mesh.facesTop)
vVelocity.constrain(0., mesh.exteriorFaces)
U, V = mesh.faceCenters
pressureCorrection.constrain(0., mesh.facesLeft & (V < nlat))
if __name__ == '__main__':
    viewer = Viewer(vars=(pressure, uVelocity, vVelocity, velocity),
                    xmin=min(longitudes), xmax = max(longitudes), ymin = min(latitudes), ymax = max(latitudes), colorbar='vertical', scale = 5)
    from builtins import range
for sweep in range(sweeps):
    ## solve the Stokes equations to get starred values
    uVelocityEq.cacheMatrix()
    ures = uVelocityEq.sweep(var=uVelocity,underRelaxation=velocityRelaxation)
    umat = uVelocityEq.matrix
    vres = vVelocityEq.sweep(var=vVelocity,underRelaxation=velocityRelaxation)

    ## update the ap coefficient from the matrix diagonal
    ap[:] = -numerix.asarray(umat.takeDiagonal())

    ## update the face velocities based on starred values with the
    ## Rhie-Chow correction.
   ## cell pressure gradient
    presgrad = pressure.grad

    ## face pressure gradient
    facepresgrad = _FaceGradVariable(pressure)
    velocity[0] = uVelocity.arithmeticFaceValue + contrvolume / ap.arithmeticFaceValue * (presgrad[0].arithmeticFaceValue-facepresgrad[0])
    velocity[1] = vVelocity.arithmeticFaceValue + contrvolume / ap.arithmeticFaceValue * (presgrad[1].arithmeticFaceValue-facepresgrad[1])
    velocity[..., mesh.exteriorFaces.value] = 0.
    velocity[0, mesh.facesTop.value] = u_

    ## solve the pressure correction equation
    pressureCorrectionEq.cacheRHSvector()

    ## left bottom point must remain at pressure 0, so no correction
    pres = pressureCorrectionEq.sweep(var=pressureCorrection)
    rhs = pressureCorrectionEq.RHSvector
    ## update the pressure using the corrected value
    pressure.setValue(pressure + pressureRelaxation * pressureCorrection )

    ## update the velocity using the corrected pressure
    uVelocity.setValue(uVelocity - pressureCorrection.grad[0] / ap * mesh.cellVolumes)
    vVelocity.setValue(vVelocity - pressureCorrection.grad[1] / ap * mesh.cellVolumes)


    if __name__ == '__main__':
        if sweep%10 == 0:
            print('sweep:', sweep, ', u residual:', ures, ', v residual', vres, ', p residual:', pres, ', continuity:', max(abs(rhs)))
            viewer.plot()

# %%
mesh = Grid2D(nx = len(latitudes), ny = len(longitudes), dx = nlong, dy = nlat)

# %%
pressure = CellVariable(mesh = mesh, name = 'pressure')
pressureCorrection = CellVariable(mesh = mesh)
uVelocity = CellVariable(mesh = mesh, name = 'u velocity')
vVelocity = CellVariable(mesh = mesh, name = 'v velocity')

# %%
velocity = FaceVariable(mesh = mesh, rank=1) #??

# %%
viscosity = 14.88 * 10e-6
u_ = 1. #??? 
pressureRelaxation = 0.8
velocityRelaxation = 0.5

# %%
if __name__ == '__main__':
    sweeps = 300
else:
    sweeps = 5

# %%
uVelocityEq = DiffusionTerm(coeff=viscosity) -  pressure.grad.dot([1., 0.])
vVelocityEq = DiffusionTerm(coeff=viscosity) -  pressure.grad.dot([0., 1.])

# %%
ap = CellVariable(mesh = mesh, value = 1.)
coeff = 1./ap.arithmeticFaceValue*mesh._faceAreas * mesh._cellDistances
pressureCorrectionEq = DiffusionTerm(coeff = coeff) - velocity.divergence

# %%
from fipy.variables.faceGradVariable import _FaceGradVariable

# %%
volume = CellVariable(mesh = mesh, value = mesh.cellVolumes, name="Volume")
contrvolume = volume.arithmeticFaceValue

# %%
uVelocity.constrain(0., mesh.facesRight | mesh.facesLeft | mesh.facesBottom)
uVelocity.constrain(u_, mesh.facesTop)
vVelocity.constrain(0., mesh.exteriorFaces)
U, V = mesh.faceCenters
pressureCorrection.constrain(0., mesh.facesLeft & (V < nlat))

# %%
if __name__ == '__main__':
    viewer = Viewer(vars=(pressure, uVelocity, vVelocity, velocity),
                    xmin=min(longitudes), xmax = max(longitudes), ymin = min(latitudes), ymax = max(latitudes), colorbar='vertical', scale = 5)

# %%
from builtins import range
for sweep in range(sweeps):
    ## solve the Stokes equations to get starred values
    uVelocityEq.cacheMatrix()
    ures = uVelocityEq.sweep(var=uVelocity,underRelaxation=velocityRelaxation)
    umat = uVelocityEq.matrix
    vres = vVelocityEq.sweep(var=vVelocity,underRelaxation=velocityRelaxation)

    ## update the ap coefficient from the matrix diagonal
    ap[:] = -numerix.asarray(umat.takeDiagonal())

    ## update the face velocities based on starred values with the
    ## Rhie-Chow correction.
   ## cell pressure gradient
    presgrad = pressure.grad

    ## face pressure gradient
    facepresgrad = _FaceGradVariable(pressure)
    velocity[0] = uVelocity.arithmeticFaceValue + contrvolume / ap.arithmeticFaceValue * (presgrad[0].arithmeticFaceValue-facepresgrad[0])
    velocity[1] = vVelocity.arithmeticFaceValue + contrvolume / ap.arithmeticFaceValue * (presgrad[1].arithmeticFaceValue-facepresgrad[1])
    velocity[..., mesh.exteriorFaces.value] = 0.
    velocity[0, mesh.facesTop.value] = u_

    ## solve the pressure correction equation
    pressureCorrectionEq.cacheRHSvector()

    ## left bottom point must remain at pressure 0, so no correction
    pres = pressureCorrectionEq.sweep(var=pressureCorrection)
    rhs = pressureCorrectionEq.RHSvector
    ## update the pressure using the corrected value
    pressure.setValue(pressure + pressureRelaxation * pressureCorrection )

    ## update the velocity using the corrected pressure
    uVelocity.setValue(uVelocity - pressureCorrection.grad[0] / ap * mesh.cellVolumes)
    vVelocity.setValue(vVelocity - pressureCorrection.grad[1] / ap * mesh.cellVolumes)


    if __name__ == '__main__':
        if sweep%10 == 0:
            print('sweep:', sweep, ', u residual:', ures, ', v residual', vres, ', p residual:', pres, ', continuity:', max(abs(rhs)))
            viewer.plot()

# %%
print(numerix.allclose(pressure.globalValue[..., -1], 162))
# Out:
# False

# %%
type(wind_data_u_grid)
# Out:
# numpy.ndarray

# %%
plt.imshow(wind_data_u_grid)
plt.show()

# %%
wind_data_interp_v = plot(f_v, longitudes_interp, latitudes_interp, wind_data_v_grid)

# %% [raw]
# from scipy.interpolate import interp2d, RectBivariateSpline
# wind_data_u_grid = np.empty([len(latitudes), len(longitudes)], dtype = float)
# print(wind_data_u_grid.shape)
# wind_data_u_grid[:] = wind_data['u'].values[:wind_data_u_grid.size].reshape((16,11))
#
# f_u = interp2d(longitudes,latitudes, tmp)

# %%
plt.imshow(wind_data_v_grid)
plt.show()

# %% [markdown]
# # Obtention des données pour le test

# %%
import numpy as np
import random

# %%
def generate_random_list(taille, borneInf, borneSup):
    return [round(random.uniform(borneInf, borneSup), 2) for _ in range(taille)]

nb_points_test = 100
latitudes_test = generate_random_list(nb_points_test, 41.5, 43)
longitudes_test = generate_random_list(nb_points_test, 8.5, 9.5)

# %%
import openmeteo_requests

import requests_cache
import pandas as pd
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
url = "https://archive-api.open-meteo.com/v1/archive"
params_test = {
	"latitude": latitudes_test,
	"longitude": longitudes_test,
	"start_date": "2024-09-09",
	"end_date": "2024-09-09",
	"hourly": ["wind_speed_10m", "wind_direction_10m"]
}
responses_test = openmeteo.weather_api(url, params=params_test)

# %%
# Création du DataFrame à partir des coordonnées
wind_data_test = pd.DataFrame({'lat': latitudes_test, 'lon': longitudes_test, 'u': 0.0, 'v':0.0, 'u_interp' : 0.0, 'v_interp' : 0.0})

# %%
for i in range(len(latitudes_test)): #l_latitude correspond au nombre de points de la grille
    data_test = responses_test[i] #On prend le i-ème point de la grille
    
    hourl_test = data_test.Hourly() #On va chercher les données par heure
    hourl_wind_speed_10m_test = hourl_test.Variables(0).ValuesAsNumpy()
    hourl_wind_direction_10m_test = hourl_test.Variables(1).ValuesAsNumpy()
    hourl_data_test = {"date": pd.date_range(
        start = pd.to_datetime(hourl_test.Time(), unit = "s", utc = True),
        end = pd.to_datetime(hourl_test.TimeEnd(), unit = "s", utc = True),
        freq = pd.Timedelta(seconds = hourl_test.Interval()),
        inclusive = "left"
    )}
    hourl_data_test["wind_speed_10m"] = hourl_wind_speed_10m_test
    hourl_data_test["wind_direction_10m"] = hourl_wind_direction_10m_test

    hourl_dataframe_test = pd.DataFrame(data = hourl_data_test)
    
    wind_spd_tmp = hourl_data_test["wind_speed_10m"][0] #0 correspond à l'heure 0h00 de la journée du 09/09/2024
    wind_dir_tmp = hourl_data_test["wind_direction_10m"][0]
    wind_direction_radians = np.deg2rad(wind_dir_tmp)
    
    wind_data_test.at[i, 'u'] = wind_spd_tmp * np.cos(wind_direction_radians)
    wind_data_test.at[i, 'v'] = wind_spd_tmp * np.sin(wind_direction_radians)

# %%
print(wind_data_test)
# Out:
#       lat   lon          u          v  u_interp  v_interp
# 0   42.90  9.34 -11.520060 -32.039974       0.0       0.0
# 1   42.45  8.72  -9.359989  -6.840014       0.0       0.0
# 2   41.83  9.45   0.359993  -7.560000       0.0       0.0
# 3   42.23  8.54   0.359994  -2.880001       0.0       0.0
# 4   42.13  9.24  -1.800007  -6.839998       0.0       0.0
# ..    ...   ...        ...        ...       ...       ...
# 95  42.51  8.66 -11.519983 -11.160017       0.0       0.0
# 96  42.14  9.30  -1.799999  -1.440001       0.0       0.0
# 97  41.72  9.25   4.320002 -10.079999       0.0       0.0
# 98  42.19  9.23  -1.440001  -2.159999       0.0       0.0
# 99  42.77  8.57 -11.160046 -30.959986       0.0       0.0
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from matplotlib.lines import Line2D

# Création de la carte
plt.figure(figsize=(10, 10))
ax = plt.axes(projection=ccrs.Mercator())

# Tracer les contours de la Corse
ax.coastlines()
ax.set_extent([8.25, 9.6, 41.2, 43.1], crs=ccrs.PlateCarree())
ax.set_title("Direction et vitesse des vents test à l'heure 0")

# Tracer les vecteurs de vent
quiver1 = ax.quiver(wind_data_test['lon'], wind_data_test['lat'], wind_data_test['u'], wind_data_test['v'], scale=100, transform=ccrs.PlateCarree(), color='r', label='Vent Observé')
quiver2 = ax.quiver(wind_data_test['lon'], wind_data_test['lat'], wind_data_test['u_interp'], wind_data_test['v_interp'], scale=100, transform=ccrs.PlateCarree(), color='b', label='Vent Interpolé')

# Créer des éléments de légende
legend_elements = [
    Line2D([0], [0], color='red', lw=2, label='Vent Observé'),
    Line2D([0], [0], color='blue', lw=2, label='Vent Interpolé')
]

# Ajouter la légende
ax.legend(handles=legend_elements, loc='upper right')

plt.show()

# %%
wind_data_test['u'][0]
# Out:
# np.float64(-11.520059585571289)

# %%
error_L1 = 0
error_L2 = 0
for i in range(nb_points_test):
    u_interpolated_test = test_u_interp(latitudes_test[i], longitudes_test[i])
    v_interpolated_test = test_v_interp(latitudes_test[i], longitudes_test[i])
    wind_data_test.loc[i, 'u_interp'] = u_interpolated_test
    wind_data_test.loc[i, 'v_interp'] = v_interpolated_test
    error_L1 += np.abs(u_interpolated_test - wind_data_test.loc[i, 'u']) + np.abs(v_interpolated_test - wind_data_test.loc[i, 'v'])
    error_L2 += (u_interpolated_test - wind_data_test['u'][i])**2 + (v_interpolated_test - wind_data_test['v'][i])**2

# %%
print(error_L1, error_L2)
# Out:
# [[458.06318505]] [[2690.64139836]]

# %%
print(wind_data_test.head(20))
# Out:
#       lat   lon          u          v   u_interp   v_interp
# 0   42.90  9.34 -11.520060 -32.039974 -11.483510 -31.731617
# 1   42.45  8.72  -9.359989  -6.840014 -11.300405  -9.265398
# 2   41.83  9.45   0.359993  -7.560000  -3.600710  -1.546595
# 3   42.23  8.54   0.359994  -2.880001   0.165331  -1.897971
# 4   42.13  9.24  -1.800007  -6.839998  -1.422587  -6.636454
# 5   42.01  9.05  -2.880002  -4.319998  -3.475993  -7.196134
# 6   41.95  9.18  -2.519999  -1.080001  -3.594362 -11.510033
# 7   41.84  9.33   0.359993  -7.560000   0.716768  -6.358724
# 8   42.53  9.20   2.879995  -3.240005   2.409226  -5.824153
# 9   42.18  9.19  -2.159997  -3.600002  -2.030621  -3.580868
# 10  41.55  8.85   5.400014 -13.319994   5.286881 -12.861096
# 11  41.71  9.12   4.320002 -10.079999   4.477885 -11.044705
# 12  41.84  8.85  -0.360001   1.440000   1.553498  -2.552740
# 13  41.59  8.81   5.039981  -9.360009   5.443115 -13.476020
# 14  42.01  9.28  -2.519997  -1.800004  -2.548830  -3.785352
# 15  42.94  8.72 -14.760008 -33.839996 -16.534495 -35.302150
# 16  42.14  8.59   2.160001  -5.039999  -0.068825  -1.930623
# 17  42.30  9.24  -0.359994  -3.240000  -0.271073  -3.187076
# 18  42.73  9.05  -3.959952 -28.800007  -5.746638 -32.601955
# 19  42.58  8.55  -9.360030 -24.839987  -7.898067 -25.862985

# %% [markdown]
# # Création d'un vtk

# %%
# !pip install vtk
# Out:
# Collecting vtk
#   Downloading vtk-9.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from vtk) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (24.1)
# Requirement already satisfied: pillow>=8 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from matplotlib>=2.0.0->vtk) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/hleroy/mon_venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->vtk) (1.16.0)
# Downloading vtk-9.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (92.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:02
# Installing collected packages: vtk
# Successfully installed vtk-9.3.1

# %%
print(min(latitudes), max(latitudes), min(longitudes), max(longitudes))
# Out:
# 41.5 43.00000000000002 8.5 9.499999999999996

# %%
import numpy as np
from scipy.interpolate import RectBivariateSpline
import vtk

# %%
test_vtk_u_interp = RectBivariateSpline(latitudes,longitudes,wind_data_u_grid, bbox=[min(latitudes), max(latitudes), min(longitudes), max(longitudes)])
test_vtk_v_interp = RectBivariateSpline(latitudes,longitudes,wind_data_v_grid, bbox=[min(latitudes), max(latitudes), min(longitudes), max(longitudes)])


latitudes_new = np.linspace(41.5, 43, 100)
longitudes_new = np.linspace(8.5, 9.5, 100)
u_new = test_vtk_u_interp(latitudes_new, longitudes_new)
v_new = test_vtk_v_interp(latitudes_new, longitudes_new)

# %%
def create_vtk_from_vector_field(x, y, u, v):
    # Dimensions
    nx, ny = u.shape

    # Création d'une grille rectangulaire
    grid = vtk.vtkStructuredPoints()
    grid.SetDimensions(nx, ny, 1)  # Un seul niveau en Z

    # Création d'un tableau pour les vecteurs
    vectors = vtk.vtkDoubleArray()
    vectors.SetName("VectorField")
    vectors.SetNumberOfComponents(2)  # Deux composantes (u et v)

    # Ajout des vecteurs à la grille
    for i in range(nx):
        for j in range(ny):
            # Insert les vecteurs à la position (i, j)
            vectors.InsertNextTuple2(u[i, j], v[i, j])

    # Ajout des vecteurs à la grille
    grid.GetPointData().SetVectors(vectors)

    # Écriture dans un fichier VTK
    writer = vtk.vtkStructuredPointsWriter()
    writer.SetFileName("vector_field.vtk")  # Format VTK
    writer.SetInputData(grid)
    writer.Write()

# %%
# Appel de la fonction
create_vtk_from_vector_field(latitudes_new, longitudes_new, u_new, v_new)
# Out:
# 2024-10-02 15:20:57.105 ( 534.767s) [    75209EDE5080]vtkDataSetAttributes.cx:1655  WARN| vtkPointData (0x64f7fe0): Can not set attribute Vectors. Incorrect number of components.

# %%
print(u_new.shape, v_new.shape, len(latitudes_new), len(longitudes_new))
# Out:
# (100, 100) (100, 100) 100 100

# %%
tmp = np.empty([len(latitudes), len(longitudes)], dtype = float)

# %%
wind_data['u'].values.size
# Out:
# 176

# %%
tmp.size
# Out:
# 176

# %%
N_sparse = 6
u_mesh = np.zeros((len(t1), len(t2)))
epsilon = 1e-1
for long, lat in zip(t1, t2):
    tmp = 0
    for i in range(len(long)):
        matches = (
            (np.abs(wind_data['lon'] - long[i]) < epsilon) &
            (np.abs(wind_data['lat'] - lat[i]) < epsilon)
        )
        u_values = wind_data.loc[matches, 'u']
        #print(long[i], lat[i])
        #print(wind_data.at[i, 'lon'])
        #print(wind_data.at[i, 'lat'])
        #print(wind_data.loc[wind_data['lon'] == long[i], 'u'])
        #u_mesh[tmp, i] = wind_data.loc[(wind_data['lon'] == round(long[i], 1)) & (wind_data['lat'] == lat[i]), 'u'].values
        #print(wind_data.loc[(round(wind_data['lon'], 1) == round(long[i], 1)) & (round(wind_data['lat'], 1) == round(lat[i], 1)), 'u'].values)

# %%
print(u_values.values)
# Out:
# []

# %%
print(wind_data.loc[(wind_data['lon'] == 8.5) & (wind_data['lat'] == 41.6), 'u'])
# Out:
# 11    13.319978
# Name: u, dtype: float64

# %%
print(wind_data.head(40))
# Out:
#      lat  lon          u          v
# 0   41.5  8.5   8.640039 -24.119986
# 1   41.5  8.6   8.640039 -24.119986
# 2   41.5  8.7   6.840027 -23.039993
# 3   41.5  8.8   5.400022 -16.559992
# 4   41.5  8.9   5.400022 -16.559992
# 5   41.5  9.0   5.400022 -16.559992
# 6   41.5  9.1   5.400022 -16.559992
# 7   41.5  9.2   5.040019 -14.759993
# 8   41.5  9.3  -0.359996 -18.000000
# 9   41.5  9.4  -0.359996 -18.000000
# 10  41.5  9.5 -11.880054 -36.359982
# 11  41.6  8.5  13.319978 -21.960014
# 12  41.6  8.6   9.360011 -22.319996
# 13  41.6  8.7   5.400014 -13.319994
# 14  41.6  8.8   5.400014 -13.319994
# 15  41.6  8.9   4.679984  -9.000009
# 16  41.6  9.0   5.039981  -9.360009
# 17  41.6  9.1   4.679984  -9.000009
# 18  41.6  9.2  -1.799977 -12.960003
# 19  41.6  9.3  -1.799977 -12.960003
# 20  41.6  9.4  -1.799977 -12.960003
# 21  41.6  9.5 -18.720005 -28.799992
# 22  41.7  8.5  15.120026 -21.959980
# 23  41.7  8.6  12.959956 -24.120022
# 24  41.7  8.7   2.880000  -6.480000
# 25  41.7  8.8   2.880000  -6.480000
# 26  41.7  8.9   2.880000  -6.480000
# 27  41.7  9.0   2.879995  -3.240005
# 28  41.7  9.1   4.320002 -10.079999
# 29  41.7  9.2   4.320002 -10.079999
# 30  41.7  9.3   2.159982 -12.240003
# 31  41.7  9.4  -6.839988  -7.920010
# 32  41.7  9.5  -6.839988  -7.920010
# 33  41.8  8.5  15.120032 -20.519974
# 34  41.8  8.6   6.120028 -17.639990
# 35  41.8  8.7   6.120028 -17.639990
# 36  41.8  8.8   0.720003  -2.519999
# 37  41.8  8.9   1.079997  -2.160001
# 38  41.8  9.0   1.079997  -2.160001
# 39  41.8  9.1   2.880003 -11.520000

# %%
wind_data_u = np.zeros((len(latitudes), len(longitudes)))
wind_data_v = np.zeros((len(latitudes), len(longitudes)))

# %%
print(longitudes[10])
print(latitudes[15])
# Out:
# 9.499999999999996
# 43.00000000000002

# %%
for i in range(len(latitudes)):
    for j in range(len(longitudes)):
        wind_data_u[i, j] = wind_data.loc[(wind_data['lon'] == round(longitudes[j],1)) & (wind_data['lat'] == round(latitudes[i],1)), 'u']
        wind_data_u[i, j] = wind_data.loc[(wind_data['lon'] == round(longitudes[j],1)) & (wind_data['lat'] == round(latitudes[i],1)), 'v']
# Out:
# /tmp/ipykernel_4044/1314122648.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   wind_data_u[i, j] = wind_data.loc[(wind_data['lon'] == round(longitudes[j],1)) & (wind_data['lat'] == round(latitudes[i],1)), 'u']
# /tmp/ipykernel_4044/1314122648.py:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   wind_data_u[i, j] = wind_data.loc[(wind_data['lon'] == round(longitudes[j],1)) & (wind_data['lat'] == round(latitudes[i],1)), 'v']

# %%
for i in range(len(latitudes)):
    for j in range(len(longitudes)):
        print(round(latitudes[i],1),round(longitudes[j],1), wind_data_u[i, j])
# Out:
# 41.5 8.5 -24.119985580444336
# 41.5 8.6 -24.119985580444336
# 41.5 8.7 -23.039993286132812
# 41.5 8.8 -16.55999183654785
# 41.5 8.9 -16.55999183654785
# 41.5 9.0 -16.55999183654785
# 41.5 9.1 -16.55999183654785
# 41.5 9.2 -14.759992599487305
# 41.5 9.3 -18.0
# 41.5 9.4 -18.0
# 41.5 9.5 -36.359981536865234
# 41.6 8.5 -21.96001434326172
# 41.6 8.6 -22.319995880126953
# 41.6 8.7 -13.31999397277832
# 41.6 8.8 -13.31999397277832
# 41.6 8.9 -9.000008583068848
# 41.6 9.0 -9.36000919342041
# 41.6 9.1 -9.000008583068848
# 41.6 9.2 -12.960002899169922
# 41.6 9.3 -12.960002899169922
# 41.6 9.4 -12.960002899169922
# 41.6 9.5 -28.799991607666016
# 41.7 8.5 -21.959980010986328
# 41.7 8.6 -24.12002182006836
# 41.7 8.7 -6.480000019073486
# 41.7 8.8 -6.480000019073486
# 41.7 8.9 -6.480000019073486
# 41.7 9.0 -3.2400050163269043
# 41.7 9.1 -10.079998970031738
# 41.7 9.2 -10.079998970031738
# 41.7 9.3 -12.240002632141113
# 41.7 9.4 -7.920009613037109
# 41.7 9.5 -7.920009613037109
# 41.8 8.5 -20.519973754882812
# 41.8 8.6 -17.639989852905273
# 41.8 8.7 -17.639989852905273
# 41.8 8.8 -2.5199990272521973
# 41.8 8.9 -2.160001277923584
# 41.8 9.0 -2.160001277923584
# 41.8 9.1 -11.519999504089355
# 41.8 9.2 -11.519999504089355
# 41.8 9.3 -10.79999828338623
# 41.8 9.4 -3.239997625350952
# 41.8 9.5 -3.239997625350952
# 41.9 8.5 -14.04001235961914
# 41.9 8.6 -14.04001235961914
# 41.9 8.7 -14.04001235961914
# 41.9 8.8 -14.04001235961914
# 41.9 8.9 3.240000009536743
# 41.9 9.0 -1.0800012350082397
# 41.9 9.1 -3.240002155303955
# 41.9 9.2 -11.159997940063477
# 41.9 9.3 -3.240002155303955
# 41.9 9.4 -3.240002155303955
# 41.9 9.5 2.8800148963928223
# 42.0 8.5 -19.080020904541016
# 42.0 8.6 -1.8000000715255737
# 42.0 8.7 -1.8000000715255737
# 42.0 8.8 3.599996566772461
# 42.0 8.9 -1.8000000715255737
# 42.0 9.0 -4.319998264312744
# 42.0 9.1 -11.519994735717773
# 42.0 9.2 -11.519994735717773
# 42.0 9.3 -1.8000037670135498
# 42.0 9.4 2.5199947357177734
# 42.0 9.5 2.5199947357177734
# 42.1 8.5 -19.08000946044922
# 42.1 8.6 -0.36000049114227295
# 42.1 8.7 -0.36000049114227295
# 42.1 8.8 -0.36000049114227295
# 42.1 8.9 -0.36000049114227295
# 42.1 9.0 0.7199947237968445
# 42.1 9.1 0.7199947237968445
# 42.1 9.2 -10.440001487731934
# 42.1 9.3 -1.7999982833862305
# 42.1 9.4 -3.461941844307148e-07
# 42.1 9.5 -3.461941844307148e-07
# 42.2 8.5 -2.880000591278076
# 42.2 8.6 -2.880000591278076
# 42.2 8.7 -2.1599960327148438
# 42.2 8.8 -2.1599960327148438
# 42.2 8.9 -6.8400044441223145
# 42.2 9.0 -6.480003833770752
# 42.2 9.1 -6.8400044441223145
# 42.2 9.2 -2.159999132156372
# 42.2 9.3 -2.159999132156372
# 42.2 9.4 -1.8000085353851318
# 42.2 9.5 -1.8000085353851318
# 42.3 8.5 -3.9600017070770264
# 42.3 8.6 -3.9600017070770264
# 42.3 8.7 -3.9600017070770264
# 42.3 8.8 -4.680004596710205
# 42.3 8.9 -5.759990215301514
# 42.3 9.0 -5.759990215301514
# 42.3 9.1 -3.6000020503997803
# 42.3 9.2 -3.2400004863739014
# 42.3 9.3 -3.2400004863739014
# 42.3 9.4 -3.6000020503997803
# 42.3 9.5 1.0799944400787354
# 42.4 8.5 -28.440004348754883
# 42.4 8.6 -6.8400139808654785
# 42.4 8.7 -6.8400139808654785
# 42.4 8.8 -9.359987258911133
# 42.4 8.9 -9.0
# 42.4 9.0 -9.0
# 42.4 9.1 -9.0
# 42.4 9.2 -2.1600005626678467
# 42.4 9.3 -3.2400031089782715
# 42.4 9.4 4.679999828338623
# 42.4 9.5 4.679999828338623
# 42.5 8.5 -29.52000617980957
# 42.5 8.6 -11.160017013549805
# 42.5 8.7 -11.160017013549805
# 42.5 8.8 -11.160017013549805
# 42.5 8.9 -9.0
# 42.5 9.0 -0.7199946045875549
# 42.5 9.1 -9.0
# 42.5 9.2 -3.2400050163269043
# 42.5 9.3 -3.240000009536743
# 42.5 9.4 0.720000684261322
# 42.5 9.5 0.720000684261322
# 42.6 8.5 -29.880006790161133
# 42.6 8.6 -24.83998680114746
# 42.6 8.7 -19.440013885498047
# 42.6 8.8 -19.440013885498047
# 42.6 8.9 -19.440013885498047
# 42.6 9.0 -19.440013885498047
# 42.6 9.1 -6.120001316070557
# 42.6 9.2 -15.119999885559082
# 42.6 9.3 -5.760001182556152
# 42.6 9.4 -5.760001182556152
# 42.6 9.5 -5.760001182556152
# 42.7 8.5 -30.23998260498047
# 42.7 8.6 -31.67997932434082
# 42.7 8.7 -31.67997932434082
# 42.7 8.8 -32.7599983215332
# 42.7 8.9 -34.91999435424805
# 42.7 9.0 -28.800006866455078
# 42.7 9.1 -28.800006866455078
# 42.7 9.2 -28.800006866455078
# 42.7 9.3 -28.800006866455078
# 42.7 9.4 -21.240005493164062
# 42.7 9.5 -12.240004539489746
# 42.8 8.5 -30.959985733032227
# 42.8 8.6 -31.319978713989258
# 42.8 8.7 -31.319978713989258
# 42.8 8.8 -32.039981842041016
# 42.8 8.9 -35.27998352050781
# 42.8 9.0 -38.51996994018555
# 42.8 9.1 -38.51996994018555
# 42.8 9.2 -34.91999053955078
# 42.8 9.3 -12.960000991821289
# 42.8 9.4 -12.960000991821289
# 42.8 9.5 -12.960000991821289
# 42.9 8.5 -33.1199951171875
# 42.9 8.6 -33.1199951171875
# 42.9 8.7 -33.839996337890625
# 42.9 8.8 -33.839988708496094
# 42.9 8.9 -34.55997848510742
# 42.9 9.0 -34.55997848510742
# 42.9 9.1 -35.63997268676758
# 42.9 9.2 -34.55997848510742
# 42.9 9.3 -32.039974212646484
# 42.9 9.4 -32.039974212646484
# 42.9 9.5 -32.76000213623047
# 43.0 8.5 -33.48001480102539
# 43.0 8.6 -33.48001480102539
# 43.0 8.7 -35.28002166748047
# 43.0 8.8 -36.360008239746094
# 43.0 8.9 -35.63998794555664
# 43.0 9.0 -35.63998794555664
# 43.0 9.1 -35.27997589111328
# 43.0 9.2 -35.27997970581055
# 43.0 9.3 -38.159976959228516
# 43.0 9.4 -38.159976959228516
# 43.0 9.5 -44.280006408691406

# %%
from scipy.interpolate import griddata

# Convertir les listes en tableaux numpy
latitudes = np.array(latitudes)
longitudes = np.array(longitudes)
u_values = np.array(wind_data_u)

# %%
u_values
# Out:
# array([[-2.41199856e+01, -2.41199856e+01, -2.30399933e+01,
#         -1.65599918e+01, -1.65599918e+01, -1.65599918e+01,
#         -1.65599918e+01, -1.47599926e+01, -1.80000000e+01,
#         -1.80000000e+01, -3.63599815e+01],
#        [-2.19600143e+01, -2.23199959e+01, -1.33199940e+01,
#         -1.33199940e+01, -9.00000858e+00, -9.36000919e+00,
#         -9.00000858e+00, -1.29600029e+01, -1.29600029e+01,
#         -1.29600029e+01, -2.87999916e+01],
#        [-2.19599800e+01, -2.41200218e+01, -6.48000002e+00,
#         -6.48000002e+00, -6.48000002e+00, -3.24000502e+00,
#         -1.00799990e+01, -1.00799990e+01, -1.22400026e+01,
#         -7.92000961e+00, -7.92000961e+00],
#        [-2.05199738e+01, -1.76399899e+01, -1.76399899e+01,
#         -2.51999903e+00, -2.16000128e+00, -2.16000128e+00,
#         -1.15199995e+01, -1.15199995e+01, -1.07999983e+01,
#         -3.23999763e+00, -3.23999763e+00],
#        [-1.40400124e+01, -1.40400124e+01, -1.40400124e+01,
#         -1.40400124e+01,  3.24000001e+00, -1.08000124e+00,
#         -3.24000216e+00, -1.11599979e+01, -3.24000216e+00,
#         -3.24000216e+00,  2.88001490e+00],
#        [-1.90800209e+01, -1.80000007e+00, -1.80000007e+00,
#          3.59999657e+00, -1.80000007e+00, -4.31999826e+00,
#         -1.15199947e+01, -1.15199947e+01, -1.80000377e+00,
#          2.51999474e+00,  2.51999474e+00],
#        [-1.90800095e+01, -3.60000491e-01, -3.60000491e-01,
#         -3.60000491e-01, -3.60000491e-01,  7.19994724e-01,
#          7.19994724e-01, -1.04400015e+01, -1.79999828e+00,
#         -3.46194184e-07, -3.46194184e-07],
#        [-2.88000059e+00, -2.88000059e+00, -2.15999603e+00,
#         -2.15999603e+00, -6.84000444e+00, -6.48000383e+00,
#         -6.84000444e+00, -2.15999913e+00, -2.15999913e+00,
#         -1.80000854e+00, -1.80000854e+00],
#        [-3.96000171e+00, -3.96000171e+00, -3.96000171e+00,
#         -4.68000460e+00, -5.75999022e+00, -5.75999022e+00,
#         -3.60000205e+00, -3.24000049e+00, -3.24000049e+00,
#         -3.60000205e+00,  1.07999444e+00],
#        [-2.84400043e+01, -6.84001398e+00, -6.84001398e+00,
#         -9.35998726e+00, -9.00000000e+00, -9.00000000e+00,
#         -9.00000000e+00, -2.16000056e+00, -3.24000311e+00,
#          4.67999983e+00,  4.67999983e+00],
#        [-2.95200062e+01, -1.11600170e+01, -1.11600170e+01,
#         -1.11600170e+01, -9.00000000e+00, -7.19994605e-01,
#         -9.00000000e+00, -3.24000502e+00, -3.24000001e+00,
#          7.20000684e-01,  7.20000684e-01],
#        [-2.98800068e+01, -2.48399868e+01, -1.94400139e+01,
#         -1.94400139e+01, -1.94400139e+01, -1.94400139e+01,
#         -6.12000132e+00, -1.51199999e+01, -5.76000118e+00,
#         -5.76000118e+00, -5.76000118e+00],
#        [-3.02399826e+01, -3.16799793e+01, -3.16799793e+01,
#         -3.27599983e+01, -3.49199944e+01, -2.88000069e+01,
#         -2.88000069e+01, -2.88000069e+01, -2.88000069e+01,
#         -2.12400055e+01, -1.22400045e+01],
#        [-3.09599857e+01, -3.13199787e+01, -3.13199787e+01,
#         -3.20399818e+01, -3.52799835e+01, -3.85199699e+01,
#         -3.85199699e+01, -3.49199905e+01, -1.29600010e+01,
#         -1.29600010e+01, -1.29600010e+01],
#        [-3.31199951e+01, -3.31199951e+01, -3.38399963e+01,
#         -3.38399887e+01, -3.45599785e+01, -3.45599785e+01,
#         -3.56399727e+01, -3.45599785e+01, -3.20399742e+01,
#         -3.20399742e+01, -3.27600021e+01],
#        [-3.34800148e+01, -3.34800148e+01, -3.52800217e+01,
#         -3.63600082e+01, -3.56399879e+01, -3.56399879e+01,
#         -3.52799759e+01, -3.52799797e+01, -3.81599770e+01,
#         -3.81599770e+01, -4.42800064e+01]])

# %%
# Créer une grille de points pour l'interpolation
grid_lat = np.linspace(latitudes.min(), latitudes.max(), 100)
grid_lon = np.linspace(longitudes.min(), longitudes.max(), 100)
grid_lon, grid_lat = np.meshgrid(grid_lon, grid_lat)

# %%
print(grid_lon.shape, grid_lat.shape)
# Out:
# (100, 100) (100, 100)

# %%
# Interpolation des valeurs de u
grid_u = griddata((longitudes, latitudes), u_values, (grid_lon, grid_lat), method='linear')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4044/4153093570.py in <module>
#       1 # Interpolation des valeurs de u
# ----> 2 grid_u = griddata((longitudes, latitudes), u_values, (grid_lon, grid_lat), method='linear')
#
# /usr/lib/python3/dist-packages/scipy/interpolate/_ndgriddata.py in griddata(points, values, xi, method, fill_value, rescale)
#     231     """
#     232
# --> 233     points = _ndim_coords_from_arrays(points)
#     234
#     235     if points.ndim < 2:
#
# interpnd.pyx in scipy.interpolate.interpnd._ndim_coords_from_arrays()
#
# interpnd.pyx in scipy.interpolate.interpnd._ndim_coords_from_arrays()
#
# ~/.local/lib/python3.10/site-packages/numpy/core/overrides.py in broadcast_arrays(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     538     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     539
# --> 540     shape = _broadcast_shape(*args)
#     541
#     542     if all(array.shape == shape for array in args):
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     420     # use the old-iterator because np.nditer does not handle size 0 arrays
#     421     # consistently
# --> 422     b = np.broadcast(*args[:32])
#     423     # unfortunately, it cannot handle 32 or more arguments directly
#     424     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (11,) and arg 1 with shape (16,).

# %%
# Visualisation des résultats
plt.figure(figsize=(12, 8))
plt.imshow(grid_u, extent=(longitudes.min(), longitudes.max(), latitudes.min(), latitudes.max()),
           origin='lower', cmap='viridis', alpha=0.7)
plt.scatter(longitudes, latitudes, c='red', marker='o', label='Données originales')
plt.colorbar(label='Valeurs de u')
plt.title('Interpolation des valeurs de u')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()

# %%
print(len(latitudes) , len(longitudes) )
wind_data_u.shape
# Out:
# 16 11
# (15, 10)

# %%
print(wind_data_u.shape)
print(np.min(wind_data_u,axis=0))
print(np.max(wind_data_u,axis=0))
# Out:
# (15, 10)
# [-33.11999512 -33.11999512 -33.83999634 -33.83998871 -35.27998352
#  -38.51996994 -38.51996994 -34.91999054 -32.03997421 -32.03997421]
# [-2.88000059 -0.36000049 -0.36000049  3.59999657  3.24000001  0.71999472
#   0.71999472 -2.15999913 -1.79999828  4.67999983]

# %%
plt.figure()

lims = dict(cmap='RdBu_r', vmin=-20, vmax=20)

plt.pcolormesh(latitudes, longitudes, wind_data_u, shading='flat', **lims)

plt.colorbar()

plt.title("Sparsely sampled function.")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_43100/907812464.py in <module>
#       3 lims = dict(cmap='RdBu_r', vmin=-20, vmax=20)
#       4
# ----> 5 plt.pcolormesh(latitudes, longitudes, wind_data_u, shading='flat', **lims)
#       6
#       7 plt.colorbar()
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2716         vmax=None, shading=None, antialiased=False, data=None,
#    2717         **kwargs):
# -> 2718     __ret = gca().pcolormesh(
#    2719         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2720         vmax=vmax, shading=shading, antialiased=antialiased,
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1414     def inner(ax, *args, data=None, **kwargs):
#    1415         if data is None:
# -> 1416             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1417
#    1418         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6060         kwargs.setdefault('edgecolors', 'none')
#    6061
# -> 6062         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
#    6063                                             shading=shading, kwargs=kwargs)
#    6064         coords = np.stack([X, Y], axis=-1)
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py in _pcolorargs(self, funcname, shading, *args, **kwargs)
#    5573         if shading == 'flat':
#    5574             if (Nx, Ny) != (ncols + 1, nrows + 1):
# -> 5575                 raise TypeError('Dimensions of C %s are incompatible with'
#    5576                                 ' X (%d) and/or Y (%d); see help(%s)' % (
#    5577                                     C.shape, Nx, Ny, funcname))
#
# TypeError: Dimensions of C (15, 10) are incompatible with X (16) and/or Y (11); see help(pcolormesh)

# %% [markdown]
# help(plt.pcolormesh)

# %%
from scipy.interpolate import RegularGridInterpolator

test_v = RegularGridInterpolator((np.array(latitudes), np.array(longitudes)), wind_data_v_grid)

# %%
test_v((42,8.5))
# Out:
# array(-19.0800209)

# %%
latitudes_interp = np.arange(41.5, 43.001, 1e-2)
longitudes_interp = np.arange(8.5, 9.5001, 1e-2)
wind_data_interp_v_test = plot(test_v, longitudes_interp, latitudes_interp, wind_data_v_grid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11646/3150981869.py in <module>
#       1 latitudes_interp = np.arange(41.5, 43.001, 1e-2)
#       2 longitudes_interp = np.arange(8.5, 9.5001, 1e-2)
# ----> 3 wind_data_interp_v_test = plot(test_v, longitudes_interp, latitudes_interp, wind_data_v_grid)
#
# NameError: name 'test_v' is not defined

# %%
# interpolator

ax.plot_wireframe(np.array(latitudes), np.array(longitudes), test_v((np.array(latitudes), np.array(longitudes))), rstride=3, cstride=3,

                  alpha=0.4, color='m', label='linear interp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4044/3216869083.py in <module>
#       1 # interpolator
#       2
# ----> 3 ax.plot_wireframe(np.array(latitudes), np.array(longitudes), test_v((np.array(latitudes), np.array(longitudes))), rstride=3, cstride=3,
#       4
#       5                   alpha=0.4, color='m', label='linear interp')
#
# /usr/lib/python3/dist-packages/scipy/interpolate/_interpolate.py in __call__(self, xi, method)
#    2513
#    2514         ndim = len(self.grid)
# -> 2515         xi = _ndim_coords_from_arrays(xi, ndim=ndim)
#    2516         if xi.shape[-1] != len(self.grid):
#    2517             raise ValueError("The requested sample points xi have dimension "
#
# interpnd.pyx in scipy.interpolate.interpnd._ndim_coords_from_arrays()
#
# interpnd.pyx in scipy.interpolate.interpnd._ndim_coords_from_arrays()
#
# ~/.local/lib/python3.10/site-packages/numpy/core/overrides.py in broadcast_arrays(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     538     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     539
# --> 540     shape = _broadcast_shape(*args)
#     541
#     542     if all(array.shape == shape for array in args):
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     420     # use the old-iterator because np.nditer does not handle size 0 arrays
#     421     # consistently
# --> 422     b = np.broadcast(*args[:32])
#     423     # unfortunately, it cannot handle 32 or more arguments directly
#     424     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (16,) and arg 1 with shape (11,).

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(latitudes.ravel(), longitudes.ravel(), wind_data_v_grid.ravel(), s=60, c='k', label='data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4044/1648282736.py in <module>
#       3 fig = plt.figure()
#       4 ax = fig.add_subplot(projection='3d')
# ----> 5 ax.scatter(latitudes.ravel(), longitudes.ravel(), wind_data_v_grid.ravel(), s=60, c='k', label='data')
#
# /usr/lib/python3/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1414     def inner(ax, *args, data=None, **kwargs):
#    1415         if data is None:
# -> 1416             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1417
#    1418         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/lib/python3/dist-packages/mpl_toolkits/mplot3d/axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2377         zs_orig = zs
#    2378
# -> 2379         xs, ys, zs = np.broadcast_arrays(
#    2380             *[np.ravel(np.ma.filled(t, np.nan)) for t in [xs, ys, zs]])
#    2381         s = np.ma.ravel(s)  # This doesn't have to match x, y in size.
#
# ~/.local/lib/python3.10/site-packages/numpy/core/overrides.py in broadcast_arrays(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     538     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     539
# --> 540     shape = _broadcast_shape(*args)
#     541
#     542     if all(array.shape == shape for array in args):
#
# ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     420     # use the old-iterator because np.nditer does not handle size 0 arrays
#     421     # consistently
# --> 422     b = np.broadcast(*args[:32])
#     423     # unfortunately, it cannot handle 32 or more arguments directly
#     424     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (16,) and arg 1 with shape (11,).

# %% [markdown]
# ## Interpolation avec Lagrange

# %%
import numpy as np
from scipy.interpolate import lagrange
import matplotlib.pyplot as plt

# %%
u_new = np.arange(41.5, 43.01, 0.02)
v_new = np.arange(8.5, 9.51, 0.02)

# %%
# Interpoler d'abord dans la direction x, puis y
def interpolate_lagrange_2d(x, y, values, x_new, y_new):
    # Interpolation sur chaque ligne pour chaque nouvelle valeur de x
    interpolated_rows = np.zeros((len(y), len(x_new)))
    for i, row in enumerate(values):
        # Interpoler pour chaque ligne (en fonction de x)
        lagrange_poly = lagrange(x, row)
        interpolated_rows[i] = lagrange_poly(x_new)

    # Interpolation sur chaque colonne pour chaque nouvelle valeur de y
    interpolated_values = np.zeros((len(y_new), len(x_new)))
    for j in range(len(x_new)):
        lagrange_poly = lagrange(y, interpolated_rows[:, j])
        interpolated_values[:, j] = lagrange_poly(y_new)

    return interpolated_values

# %%
# Interpoler u et v sur la nouvelle grille
u_interp = interpolate_lagrange_2d(wind_data['lon'], wind_data['lat'], wind_data['u'], u_new, v_new)
v_interp = interpolate_lagrange_2d(wind_data['lon'], wind_data['lat'], wind_data['v'], u_new, v_new)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_35306/1750500029.py in <module>
#       1 # Interpoler u et v sur la nouvelle grille
# ----> 2 u_interp = interpolate_lagrange_2d(wind_data['lon'], wind_data['lat'], wind_data['u'], u_new, v_new)
#       3 v_interp = interpolate_lagrange_2d(wind_data['lon'], wind_data['lat'], wind_data['v'], u_new, v_new)
#
# /tmp/ipykernel_35306/364739659.py in interpolate_lagrange_2d(x, y, values, x_new, y_new)
#       5     for i, row in enumerate(values):
#       6         # Interpoler pour chaque ligne (en fonction de x)
# ----> 7         lagrange_poly = lagrange(x, row)
#       8         interpolated_rows[i] = lagrange_poly(x_new)
#       9
#
# /usr/lib/python3/dist-packages/scipy/interpolate/_interpolate.py in lagrange(x, w)
#      82     p = poly1d(0.0)
#      83     for j in range(M):
# ---> 84         pt = poly1d(w[j])
#      85         for k in range(M):
#      86             if k == j:
#
# TypeError: 'float' object is not subscriptable

# %%
# Visualiser le champ vectoriel interpolé
U_new, V_new = np.meshgrid(u_new, v_new)

plt.figure(figsize=(6, 6))
plt.quiver(U_new, V_new, u_interp, v_interp)
plt.title("Champ vectoriel interpolé par Lagrange")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35306/1511059166.py in <module>
#       3
#       4 plt.figure(figsize=(6, 6))
# ----> 5 plt.quiver(U_new, V_new, u_interp, v_interp)
#       6 plt.title("Champ vectoriel interpolé par Lagrange")
#       7 plt.show()
#
# NameError: name 'u_interp' is not defined
